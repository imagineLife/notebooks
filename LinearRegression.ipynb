# %% [markdown]
# # Linear Regression

# %% [markdown]
# Let's fabricate some data that shows a roughly linear relationship between page speed and amount purchased:

# %% [markdown]
# ## Imports

# %%
# %matplotlib inline
import numpy as np
from pylab import *
from scipy import stats
import matplotlib.pyplot as plt

# %% [markdown]
# ## Make Some Data

# %%
spread = 1
howManyPoints = 1000
# pageSpeeds = np.random.normal(3.0, 1.0, howManyPoints)
# purchaseAmount = 100 - (pageSpeeds + np.random.normal(0, 0.1, howManyPoints)) * 3

pageSpeeds = np.random.normal(25, 1.0, howManyPoints)
purchaseAmount = 100 - (pageSpeeds + np.random.normal(0, spread, howManyPoints)) * 3

scatter(pageSpeeds, purchaseAmount)

# %% [markdown]
# ## Start The Regression Work

# %% [markdown]
# ### Apply scpipy stats to get linearRegression data points

# %% [markdown]
# As we only have two features, we can keep it simple and just use scipy.state.linregress:

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(pageSpeeds, purchaseAmount)
print("r-Squared:", str(r_value ** 2))
print("slope:",str(slope))
print("p_value:",str(p_value))
print("std_err:",str(std_err))
# Out:
# r-Squared: 0.482076806983433
# slope: -3.0165129060631455
# p_value: 9.520438053899001e-145
# std_err: 0.09897248575606549

# %% [markdown]
# ### Predict And Plot
# Let's use the slope and intercept we got from the regression to plot predicted values vs. observed.

# %%
fitLine = slope * pageSpeeds + intercept
plt.scatter(pageSpeeds, purchaseAmount)
plt.plot(pageSpeeds, fitLine, c='r')
plt.show()

# %% [markdown]
# ## Activity

# %% [markdown]
# Try increasing the random variation in the test data, and see what effect it has on the r-squared error value.
